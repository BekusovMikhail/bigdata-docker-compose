# %%
# !hadoop fs -mkdir /data

# %%
# !hadoop fs -ls /data

# %%
# !hadoop fs -put "NHANES_age_prediction.csv" /data/

# %%
# !hadoop fs -ls /data/
# Out:
# Found 1 items
# -rw-r--r--   3 root supergroup     119620 2023-11-17 22:21 /data/NHANES_age_prediction.csv

# %%
# !hadoop fs -cat /data/NHANES_age_prediction.csv
# Out:
# SEQN,age_group,RIDAGEYR,RIAGENDR,PAQ605,BMXBMI,LBXGLU,DIQ010,LBXGLT,LBXIN
# 73564.0,Adult,61.0,2.0,2.0,35.7,110.0,2.0,150.0,14.91
# 73568.0,Adult,26.0,2.0,2.0,20.3,89.0,2.0,80.0,3.85
# 73576.0,Adult,16.0,1.0,2.0,23.2,89.0,2.0,68.0,6.14
# 73577.0,Adult,32.0,1.0,2.0,28.9,104.0,2.0,84.0,16.15
# 73580.0,Adult,38.0,2.0,1.0,35.9,103.0,2.0,81.0,10.92
# 73581.0,Adult,50.0,1.0,2.0,23.6,110.0,2.0,100.0,6.08
# 73587.0,Adult,14.0,1.0,2.0,38.7,94.0,2.0,202.0,21.11
# 73596.0,Adult,57.0,2.0,2.0,38.3,107.0,2.0,164.0,20.93
# 73607.0,Senior,75.0,1.0,2.0,38.9,89.0,2.0,113.0,17.47
# 73610.0,Adult,43.0,1.0,1.0,28.9,90.0,2.0,95.0,3.24
# 73618.0,Adult,54.0,2.0,2.0,32.7,98.0,2.0,80.0,7.16
# 73619.0,Adult,36.0,2.0,1.0,27.3,85.0,2.0,91.0,9.86
# 73621.0,Senior,80.0,1.0,2.0,24.6,100.0,2.0,97.0,4.33
# 73633.0,Adult,43.0,2.0,2.0,30.5,102.0,2.0,124.0,12.06
# 73639.0,Senior,71.0,1.0,2.0,30.3,133.0,2.0,295.0,22.92
# 73640.0,Senior,67.0,2.0,1.0,22.1,114.0,2.0,150.0,10.09
# ...

# %%
# !hadoop jar /opt/hadoop/share/hadoop/mapreduce/hadoop-mapreduce-examples-3.3.6.jar pi 15 1800
# Out:
# Number of Maps  = 15
# Samples per Map = 1800
# Wrote input for Map #0
# Wrote input for Map #1
# Wrote input for Map #2
# Wrote input for Map #3
# Wrote input for Map #4
# Wrote input for Map #5
# Wrote input for Map #6
# Wrote input for Map #7
# Wrote input for Map #8
# Wrote input for Map #9
# Wrote input for Map #10
# Wrote input for Map #11
# Wrote input for Map #12
# Wrote input for Map #13
# Wrote input for Map #14
# Starting Job
# 2023-11-17 22:22:35 INFO  DefaultNoHARMFailoverProxyProvider:64 - Connecting to ResourceManager at resourcemanager/172.19.0.6:8032
# 2023-11-17 22:22:36 INFO  JobResourceUploader:907 - Disabling Erasure Coding for path: /tmp/hadoop-yarn/staging/root/.staging/job_1700245738364_0001
# 2023-11-17 22:22:36 INFO  FileInputFormat:300 - Total input files to process : 15
# 2023-11-17 22:22:36 INFO  JobSubmitter:202 - number of splits:15
# 2023-11-17 22:22:36 INFO  JobSubmitter:298 - Submitting tokens for job: job_1700245738364_0001
# ...

# %%
# !hadoop fs -ls /
# Out:
# Found 3 items
# drwxr-xr-x   - root supergroup          0 2023-11-17 22:21 /data
# drwx-wx-wx   - root supergroup          0 2023-11-17 22:22 /tmp
# drwxr-xr-x   - root supergroup          0 2023-11-17 22:22 /user

# %%
# !hadoop fs -ls /tmp/hadoop-yarn/staging/history/done_intermediate/root
# Out:
# Found 3 items
# -rwxrwx---   3 root supergroup      74502 2023-11-17 22:23 /tmp/hadoop-yarn/staging/history/done_intermediate/root/job_1700245738364_0001-1700248956343-root-QuasiMonteCarlo-1700248980977-15-1-SUCCEEDED-default-1700248959736.jhist
# -rwxrwx---   3 root supergroup        448 2023-11-17 22:23 /tmp/hadoop-yarn/staging/history/done_intermediate/root/job_1700245738364_0001.summary
# -rwxrwx---   3 root supergroup     275674 2023-11-17 22:23 /tmp/hadoop-yarn/staging/history/done_intermediate/root/job_1700245738364_0001_conf.xml

# %%
# !hadoop fs -cat /tmp/hadoop-yarn/staging/history/done_intermediate/root/job_1700245738364_0001-1700248956343-root-QuasiMonteCarlo-1700248980977-15-1-SUCCEEDED-default-1700248959736.jhist
# Out:
# Avro-Binary
# ...

# %%
# !hadoop fs -cat /tmp/hadoop-yarn/staging/history/done_intermediate/root/job_1700245738364_0001.summary
# Out:
# �jobId=job_1700245738364_0001,submitTime=1700248956343,launchTime=1700248959736,firstMapTaskLaunchTime=1700248962852,firstReduceTaskLaunchTime=1700248973834,finishTime=1700248980977,resourcesPerMap=1024,resourcesPerReduce=1024,numMaps=15,numReduces=1,succededMaps=15,succeededReduces=1,failedMaps=0,failedReduces=0,killedMaps=0,killedReduces=0,user=root,queue=default,status=SUCCEEDED,mapSlotSeconds=32,reduceSlotSeconds=14,jobName=QuasiMonteCarlo
